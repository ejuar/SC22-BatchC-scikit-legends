# %%
import pandas as pd
import plotly.express as px

# %%
data_path = 'data/music.csv'
music_df = pd.read_csv(data_path)

# %% [markdown]
# music_df.info()

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50005 entries, 0 to 50004
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instance_id       50000 non-null  float64
#  1   artist_name       50000 non-null  object
#  2   track_name        50000 non-null  object
#  3   popularity        50000 non-null  float64
#  4   acousticness      50000 non-null  float64
#  5   danceability      50000 non-null  float64
#  6   duration_ms       50000 non-null  float64
#  7   energy            50000 non-null  float64
#  8   instrumentalness  50000 non-null  float64
#  9   key               50000 non-null  object
#  10  liveness          50000 non-null  float64
#  11  loudness          50000 non-null  float64
#  12  mode              50000 non-null  object
#  13  speechiness       50000 non-null  float64
#  14  tempo             50000 non-null  object
#  15  obtained_date     50000 non-null  object
# ...

# %%
music_df.head(5)
# Out:
#    instance_id           artist_name            track_name  popularity  \
# 0      32894.0              Röyksopp  Röyksopp's Night Out        27.0
# 1      46652.0  Thievery Corporation      The Shining Path        31.0
# 2      30097.0        Dillon Francis             Hurricane        28.0
# 3      62177.0              Dubloadz                 Nitro        34.0
# 4      24907.0           What So Not      Divide & Conquer        32.0
#
#    acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 0       0.00468         0.652         -1.0   0.941           0.79200  A#
# 1       0.01270         0.622     218293.0   0.890           0.95000   D
# 2       0.00306         0.620     215613.0   0.755           0.01180  G#
# 3       0.02540         0.774     166875.0   0.700           0.00253  C#
# 4       0.00465         0.638     222369.0   0.587           0.90900  F#
#
#    liveness  loudness   mode  speechiness               tempo obtained_date  \
# ...

# %%
Categorical
-instance_id
-artist_name
-track_name
-key
-mode
-obtained_date
-music_genre

Numerical
-popularity
-acousticness
-danceability
-duration_ms
-energy
-instrumentalness
-liveness
-loudness
-speechiness
-tempo
-valence

# %%
music_df['music_genre'].value_counts()
# Out:
# Electronic     5000
# Anime          5000
# Jazz           5000
# Alternative    5000
# Country        5000
# Rap            5000
# Blues          5000
# Rock           5000
# Classical      5000
# Hip-Hop        5000
# Name: music_genre, dtype: int64

# %%
music_df[music_df['music_genre'] == 'Country']
# Out:
#        instance_id         artist_name                   track_name  \
# 20005      37415.0           Colt Ford        Back (with Jake Owen)
# 20006      61470.0          Luke Bryan                     Buzzkill
# 20007      76076.0   Montgomery Gentry  What Do Ya Think About That
# 20008      42527.0    Kelsea Ballerini                        Music
# 20009      75171.0       Gillian Welch                    Revelator
# ...            ...                 ...                          ...
# 25000      81423.0        Randy Travis              Honky Tonk Moon
# 25001      54138.0        Maren Morris                 80s Mercedes
# 25002      24842.0  The Avett Brothers              January Wedding
# 25003      55325.0            Upchurch                  Dirty South
# 25004      73725.0          Toby Keith                  Huckleberry
#
#        popularity  acousticness  danceability  duration_ms  energy  \
# 20005        46.0        0.1660         0.543     242666.0   0.744
# ...

# %%
music_df.dropna(inplace = True)

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 50004
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instance_id       50000 non-null  float64
#  1   artist_name       50000 non-null  object
#  2   track_name        50000 non-null  object
#  3   popularity        50000 non-null  float64
#  4   acousticness      50000 non-null  float64
#  5   danceability      50000 non-null  float64
#  6   duration_ms       50000 non-null  float64
#  7   energy            50000 non-null  float64
#  8   instrumentalness  50000 non-null  float64
#  9   key               50000 non-null  object
#  10  liveness          50000 non-null  float64
#  11  loudness          50000 non-null  float64
#  12  mode              50000 non-null  object
#  13  speechiness       50000 non-null  float64
#  14  tempo             50000 non-null  object
#  15  obtained_date     50000 non-null  object
# ...

# %%
#removing missing values
#remove ? from tempo
music_df[music_df['tempo'] != '?']
# Out:
#        instance_id           artist_name                track_name  \
# 0          32894.0              Röyksopp      Röyksopp's Night Out
# 1          46652.0  Thievery Corporation          The Shining Path
# 2          30097.0        Dillon Francis                 Hurricane
# 3          62177.0              Dubloadz                     Nitro
# 4          24907.0           What So Not          Divide & Conquer
# ...            ...                   ...                       ...
# 50000      58878.0                 BEXEY                  GO GETTA
# 50001      43557.0             Roy Woods       Drama (feat. Drake)
# 50002      39767.0                Berner  Lovin' Me (feat. Smiggz)
# 50003      57944.0             The-Dream         Shawty Is Da Shit
# 50004      63470.0     Naughty By Nature            Hip Hop Hooray
#
#        popularity  acousticness  danceability  duration_ms  energy  \
# 0            27.0       0.00468         0.652         -1.0   0.941
# ...

# %%
music_df = music_df[music_df ['tempo'] != '?']
In [53]:
music_df = music_df[music_df ['tempo'] != '?']

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40560 entries, 1 to 50004
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instance_id       40560 non-null  float64
#  1   artist_name       40560 non-null  object
#  2   track_name        40560 non-null  object
#  3   popularity        40560 non-null  float64
#  4   acousticness      40560 non-null  float64
#  5   danceability      40560 non-null  float64
#  6   duration_ms       40560 non-null  float64
#  7   energy            40560 non-null  float64
#  8   instrumentalness  40560 non-null  float64
#  9   key               40560 non-null  object
#  10  liveness          40560 non-null  float64
#  11  loudness          40560 non-null  float64
#  12  mode              40560 non-null  object
#  13  speechiness       40560 non-null  float64
#  14  tempo             40560 non-null  object
#  15  obtained_date     40560 non-null  object
# ...

# %%
#removing missing values
#remove -1 from duration_ms
music_df = music_df[music_df ['duration_ms'] != -1.]

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40560 entries, 1 to 50004
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instance_id       40560 non-null  float64
#  1   artist_name       40560 non-null  object
#  2   track_name        40560 non-null  object
#  3   popularity        40560 non-null  float64
#  4   acousticness      40560 non-null  float64
#  5   danceability      40560 non-null  float64
#  6   duration_ms       40560 non-null  float64
#  7   energy            40560 non-null  float64
#  8   instrumentalness  40560 non-null  float64
#  9   key               40560 non-null  object
#  10  liveness          40560 non-null  float64
#  11  loudness          40560 non-null  float64
#  12  mode              40560 non-null  object
#  13  speechiness       40560 non-null  float64
#  14  tempo             40560 non-null  object
#  15  obtained_date     40560 non-null  object
# ...

# %%
music_df['artist_name'].value_counts()
# Out:
# empty_field                2004
# Nobuo Uematsu               347
# Wolfgang Amadeus Mozart     327
# Johann Sebastian Bach       268
# Ludwig van Beethoven        256
#                            ...
# Eddie Floyd                   1
# The Picturebooks              1
# Vincent Ingala                1
# Klass Band Brotherhood        1
# Lost Boyz                     1
# Name: artist_name, Length: 6363, dtype: int64

# %%
columns_to_drop = ['instance_id', 'track_name']
music_df.drop(columns_to_drop, axis=1, inplace=True)

# %%
music_df.head(5)
# Out:
#             artist_name  popularity  acousticness  danceability  duration_ms  \
# 1  Thievery Corporation        31.0       0.01270         0.622     218293.0
# 2        Dillon Francis        28.0       0.00306         0.620     215613.0
# 3              Dubloadz        34.0       0.02540         0.774     166875.0
# 4           What So Not        32.0       0.00465         0.638     222369.0
# 6        Jordan Comolli        46.0       0.02890         0.572     214408.0
#
#    energy  instrumentalness key  liveness  loudness   mode  speechiness  \
# 1   0.890          0.950000   D     0.124    -7.043  Minor       0.0300
# 2   0.755          0.011800  G#     0.534    -4.617  Major       0.0345
# 3   0.700          0.002530  C#     0.157    -4.498  Major       0.2390
# 4   0.587          0.909000  F#     0.157    -6.266  Major       0.0413
# 6   0.803          0.000008   B     0.106    -4.294  Major       0.3510
#
#                 tempo obtained_date  valence music_genre
# ...

# %%
fig = px.histogram(music_df, x='loudness')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(music_df, x='valence')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(music_df, x='popularity', y='music_genre', color='music_genre')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(music_df, x='duration_ms', y='danceability')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(music_df, x='danceability', y='music_genre')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(music_df, x='liveness', y='loudness')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
